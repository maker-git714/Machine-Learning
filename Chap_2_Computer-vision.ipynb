# %% [markdown]
# # Chapter 2- Introduction to Computer Vision

# %%
import tensorflow as tf
data = tf.keras.datasets.fashion_mnist

(training_images, training_labels), (test_images, test_labels) = data.load_data()

training_images = training_images / 255.0
test_images = test_images / 255.0

model = tf.keras.models.Sequential([tf.keras.layers.Flatten(input_shape=(28, 28)),
                                   tf.keras.layers.Dense(128,
                                                        activation=tf.nn.relu),
                                   tf.keras.layers.Dense(10, activation=tf.nn.softmax)])

model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

model.fit(training_images, training_labels, epochs=50)

model.evaluate(test_images, test_labels)

classifications = model.predict(test_images)
print(classifications[0])
print(test_labels[0])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step
# Epoch 1/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4946 - accuracy: 0.8277
# Epoch 2/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3764 - accuracy: 0.8641
# Epoch 3/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3401 - accuracy: 0.8763
# Epoch 4/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3146 - accuracy: 0.8833
# Epoch 5/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2979 - accuracy: 0.8904
# Epoch 6/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2831 - accuracy: 0.8959
# Epoch 7/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2695 - accuracy: 0.9000
# Epoch 8/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2585 - accuracy: 0.9026
# Epoch 9/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2488 - accuracy: 0.9085
# Epoch 10/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2390 - accuracy: 0.9104
# Epoch 11/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2316 - accuracy: 0.9142
# Epoch 12/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2264 - accuracy: 0.9156
# Epoch 13/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2181 - accuracy: 0.9188
# Epoch 14/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2102 - accuracy: 0.9209
# Epoch 15/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2054 - accuracy: 0.9240
# Epoch 16/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1986 - accuracy: 0.9253
# Epoch 17/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1942 - accuracy: 0.9265
# Epoch 18/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1882 - accuracy: 0.9296
# Epoch 19/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1836 - accuracy: 0.9317
# Epoch 20/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1790 - accuracy: 0.9328
# Epoch 21/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1764 - accuracy: 0.9337
# Epoch 22/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1710 - accuracy: 0.9355
# Epoch 23/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1641 - accuracy: 0.9385
# Epoch 24/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1613 - accuracy: 0.9396
# Epoch 25/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1598 - accuracy: 0.9401
# Epoch 26/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1564 - accuracy: 0.9416
# Epoch 27/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1531 - accuracy: 0.9417
# Epoch 28/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1495 - accuracy: 0.9440
# Epoch 29/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1468 - accuracy: 0.9452
# Epoch 30/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1407 - accuracy: 0.9470
# Epoch 31/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1393 - accuracy: 0.9484
# Epoch 32/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1357 - accuracy: 0.9495
# Epoch 33/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1335 - accuracy: 0.9512
# Epoch 34/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1324 - accuracy: 0.9502
# Epoch 35/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1285 - accuracy: 0.9520
# Epoch 36/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1279 - accuracy: 0.9521
# Epoch 37/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1240 - accuracy: 0.9542
# Epoch 38/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1210 - accuracy: 0.9542
# Epoch 39/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1228 - accuracy: 0.9542
# Epoch 40/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1171 - accuracy: 0.9552
# Epoch 41/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1157 - accuracy: 0.9572
# Epoch 42/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1130 - accuracy: 0.9577
# Epoch 43/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1123 - accuracy: 0.9592
# Epoch 44/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1085 - accuracy: 0.9594
# Epoch 45/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1088 - accuracy: 0.9597
# Epoch 46/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1059 - accuracy: 0.9605
# Epoch 47/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1031 - accuracy: 0.9621
# Epoch 48/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1036 - accuracy: 0.9612
# Epoch 49/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1015 - accuracy: 0.9628
# Epoch 50/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0996 - accuracy: 0.9630
# 313/313 [==============================] - 1s 2ms/step - loss: 0.5078 - accuracy: 0.8908
# [4.2656593e-20 3.2489855e-18 7.4750187e-21 7.8624761e-25 2.3034405e-22
#  1.6007522e-08 6.9294729e-21 3.9547217e-07 3.3833691e-22 9.9999964e-01]
# 9

# %% [markdown]
# # Using callback to stop training at defined accuracy level

# %%
import tensorflow as tf

class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('accuracy')>0.95):
            print("\nReached 95% accuracy so cancelling training!")
            self.model.stop_training = True
            
callbacks = myCallback()
mnist = tf.keras.datasets.fashion_mnist

(training_images, training_labels), (test_images, test_labels) = mnist.load_data()

training_images = training_images / 255.0
test_images = test_images / 255.0

model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation=tf.nn.relu),
    tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])

model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

model.fit(training_images, training_labels, epochs=50,
         callbacks=[callbacks])
